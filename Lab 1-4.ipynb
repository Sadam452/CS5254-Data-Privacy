# %% [markdown]
# # Apply 3 perturbation techniques
# # Lab 1

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/employees.csv')
data.head()
# Out:
#   First Name Last Name                              Email  \
# 0       Jose     Lopez     joselopez0944@slingacademy.com
# 1      Diane    Carter   dianecarter1228@slingacademy.com
# 2      Shawn    Foster   shawnfoster2695@slingacademy.com
# 3     Brenda    Fisher  brendafisher3185@slingacademy.com
# 4       Sean    Hunter    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   25            Project Manager
# 1          881.633.0107  female   26  Machine Learning Engineer
# 2  001-966-861-0065x493    male   37            Project Manager
# 3      001-574-564-4648  female   31              Web Developer
# 4            5838355842    male   35            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8500    Product
# 1                    2    7000    Product
# 2                   14   17000    Product
# 3                    8   10000    Product
# ...

# %%
#three perturbation techniques are: Add Noise; Data Swapping; Synthetic Data Generation.
#noise
data['Salary'] = data['Salary'] + np.random.randint(-1000, 1000, len(data))
data['Age'] = data['Age'] + np.random.randint(-2, 2, len(data))
data.head()
# Out:
#   First Name Last Name                              Email  \
# 0       Jose     Lopez     joselopez0944@slingacademy.com
# 1      Diane    Carter   dianecarter1228@slingacademy.com
# 2      Shawn    Foster   shawnfoster2695@slingacademy.com
# 3     Brenda    Fisher  brendafisher3185@slingacademy.com
# 4       Sean    Hunter    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   25            Project Manager
# 1          881.633.0107  female   27  Machine Learning Engineer
# 2  001-966-861-0065x493    male   35            Project Manager
# 3      001-574-564-4648  female   31              Web Developer
# 4            5838355842    male   33            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8538    Product
# 1                    2    6854    Product
# 2                   14   17169    Product
# 3                    8    9125    Product
# ...

# %%
#Synthetic data generation
print(min(data['Age']), max(data['Age']))
# Out:
# 21 41

# %%
data['Age'] = np.random.randint(min(data['Age']), max(data['Age']), len(data))
data.head()
# Out:
#   First Name Last Name                              Email  \
# 0       Jose     Lopez     joselopez0944@slingacademy.com
# 1      Diane    Carter   dianecarter1228@slingacademy.com
# 2      Shawn    Foster   shawnfoster2695@slingacademy.com
# 3     Brenda    Fisher  brendafisher3185@slingacademy.com
# 4       Sean    Hunter    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   37            Project Manager
# 1          881.633.0107  female   37  Machine Learning Engineer
# 2  001-966-861-0065x493    male   26            Project Manager
# 3      001-574-564-4648  female   22              Web Developer
# 4            5838355842    male   23            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8538    Product
# 1                    2    6854    Product
# 2                   14   17169    Product
# 3                    8    9125    Product
# ...

# %%
#synthetic
data['Age'] = np.random.choice(data['Age'], len(data))
data.head(5)
# Out:
#   First Name Last Name                              Email  \
# 0       Jose     Lopez     joselopez0944@slingacademy.com
# 1      Diane    Carter   dianecarter1228@slingacademy.com
# 2      Shawn    Foster   shawnfoster2695@slingacademy.com
# 3     Brenda    Fisher  brendafisher3185@slingacademy.com
# 4       Sean    Hunter    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   35            Project Manager
# 1          881.633.0107  female   37  Machine Learning Engineer
# 2  001-966-861-0065x493    male   34            Project Manager
# 3      001-574-564-4648  female   28              Web Developer
# 4            5838355842    male   25            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8500    Product
# 1                    2    7000    Product
# 2                   14   17000    Product
# 3                    8   10000    Product
# ...

# %%
#swapping & synthetic
data['First Name'], data['Last Name'] = data['Last Name'], data['First Name']
data['First Name'] = np.random.choice(data['First Name'], len(data))
data['Last Name'] = np.random.choice(data['Last Name'], len(data))
data.head()
# Out:
#   First Name  Last Name                              Email  \
# 0     Cheryl      Brown     joselopez0944@slingacademy.com
# 1      James   Gonzalez   dianecarter1228@slingacademy.com
# 2      Tammy  Henderson   shawnfoster2695@slingacademy.com
# 3      Jamie      Perry  brendafisher3185@slingacademy.com
# 4    Charles      Jones    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   35            Project Manager
# 1          881.633.0107  female   37  Machine Learning Engineer
# 2  001-966-861-0065x493    male   34            Project Manager
# 3      001-574-564-4648  female   28              Web Developer
# 4            5838355842    male   25            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8500    Product
# 1                    2    7000    Product
# 2                   14   17000    Product
# 3                    8   10000    Product
# ...

# %%
#Masking the data
data['Phone'] = data['Phone'].apply(lambda x: x[:7]+"***")
data.head()
# Out:
#   First Name  Last Name                              Email       Phone  \
# 0     Cheryl      Brown     joselopez0944@slingacademy.com  +1-971-***
# 1      James   Gonzalez   dianecarter1228@slingacademy.com  881.633***
# 2      Tammy  Henderson   shawnfoster2695@slingacademy.com  001-966***
# 3      Jamie      Perry  brendafisher3185@slingacademy.com  001-574***
# 4    Charles      Jones    seanhunter4753@slingacademy.com  5838355***
#
#    Gender  Age                  Job Title  Years Of Experience  Salary  \
# 0    male   35            Project Manager                    1    8500
# 1  female   37  Machine Learning Engineer                    2    7000
# 2    male   34            Project Manager                   14   17000
# 3  female   28              Web Developer                    8   10000
# 4    male   25            Project Manager                   11   14500
#
#   Department
# 0    Product
# 1    Product
# 2    Product
# 3    Product
# 4    Product

# %% [markdown]
# # K-Anonimyzation
# # Lab 2

# %%
qa = ['Age', 'Gender', 'Salary']
df = data[qa]
df.head()
# Out:
#    Age  Gender  Salary
# 0   35    male    8500
# 1   37  female    7000
# 2   34    male   17000
# 3   28  female   10000
# 4   25    male   14500

# %%
def isKAnony(k):
  df['count'] = df.apply(lambda row: ','.join(row.values.astype(str)), axis=1).copy()
  counts = df['count'].value_counts()
  counts_k = counts[counts<k]
  if len(counts_k)>0:
    print("Not anonymized",len(counts_k))
  else:
    print("K-Anonymized.")

# %%
isKAnony(3)
# Out:
# Not anonymized
# <ipython-input-60-7ca6031ddee0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'] = df.apply(lambda row: ','.join(row.values.astype(str)), axis=1).copy()

# %%
df = data[qa]
df.head()
# Out:
#    Age  Gender  Salary
# 0   35    male    8500
# 1   37  female    7000
# 2   34    male   17000
# 3   28  female   10000
# 4   25    male   14500

# %%
def anonymizeAge(age):
  if age < 30:
    return "Young"
  elif age < 40:
    return "Middle Aged"
  else:
    return "Old Aged"

def anonymizeGender(Gender):
  return "Any Sex"

def anonymizeSalary(Salary):
  if Salary < 50000:
    return "<50k"
  elif Salary < 100000:
    return "<100k"
  else:
    return ">=100k"

# %%
df['Age'] = df['Age'].apply(anonymizeAge)
df['Gender'] = df['Gender'].apply(anonymizeGender)
df['Salary'] = df['Salary'].apply(anonymizeSalary)
df.head()
# Out:
# <ipython-input-68-c8f70242d8de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].apply(anonymizeAge)
# <ipython-input-68-c8f70242d8de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].apply(anonymizeGender)
# <ipython-input-68-c8f70242d8de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
isKAnony(3)
# Out:
# K-Anonymized.
# <ipython-input-60-7ca6031ddee0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'] = df.apply(lambda row: ','.join(row.values.astype(str)), axis=1).copy()

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
adult = fetch_ucirepo(id=2)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Mon Aug 07 2023', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': 'Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((A
# ...

# %%
# files.upload()

# %%
import zipfile
with zipfile.ZipFile("/content/adult.zip", "r") as ref:
  ref.extractall()

# %%
x = adult.data.features

# %%
y = pd.read_csv("/content/adult.test")

# %%
x.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0          2174             0              40  United-States
# ...

# %%
cols = ['age', 'education', 'race', 'sex', 'relationship']
released_data = x[cols]
released_data.head()
# Out:
#    age  education   race     sex   relationship
# 0   39  Bachelors  White    Male  Not-in-family
# 1   50  Bachelors  White    Male        Husband
# 2   38    HS-grad  White    Male  Not-in-family
# 3   53       11th  Black    Male        Husband
# 4   28  Bachelors  Black  Female           Wife

# %%
def isAnony(r, k):
  counts = r.groupby(cols).nunique()
  counts_k = counts[counts<k]
  return len(counts_k)

# %%
isAnony(released_data, 2)
# Out:
# 8114

# %%
released_data['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
released_data['relationship'].unique()
# Out:
# array(['Not-in-family', 'Husband', 'Wife', 'Own-child', 'Unmarried',
#        'Other-relative'], dtype=object)

# %%
def a_age(age):
  if age <30:
    return "young"
  elif age <50:
    return "middle aged"
  else:
    return "old"

def a_education(education):
  if education == "Bachelors" or education=="Masters":
    return "Hgr Studies"
  else:
    return "Lower studies"

def a_race(race):
  return "Any Race"

def a_sex(sex):
  return "Any Sex"

def a_relationship(relationship):
  family = ['Husband', 'Wife', 'Own-child']
  if relationship in family:
    return "family"
  else:
    return "Non-family"

# %%
released_data['age'] = released_data['age'].apply(a_age)
released_data['education'] = released_data['education'].apply(a_education)
released_data['race'] = released_data['race'].apply(a_race)
released_data['sex'] = released_data['sex'].apply(a_sex)
released_data['relationship'] = released_data['relationship'].apply(a_relationship)
released_data.head()
# Out:
# <ipython-input-109-2a7f94f5f3a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   released_data['age'] = released_data['age'].apply(a_age)
# <ipython-input-109-2a7f94f5f3a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   released_data['education'] = released_data['education'].apply(a_education)
# <ipython-input-109-2a7f94f5f3a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
val = isAnony(released_data, 2)

# %%
tot = len(released_data)
if val < 0.001*tot:
  print("Dataset anonymized successfully.")
else:
  print("K-anonymization property not satisfied.")
# Out:
# Dataset anonymized successfully.

# %% [markdown]
# # X-Y anonymity

# %%
y = adult.data.targets
y.head(5)
# Out:
#   income
# 0  <=50K
# 1  <=50K
# 2  <=50K
# 3  <=50K
# 4  <=50K

# %%
merged_df = pd.concat([released_data, y], axis=1)
merged_df.head()
# Out:
#            age      education      race      sex relationship income
# 0  middle aged    Hgr Studies  Any Race  Any Sex   Non-family  <=50K
# 1          old    Hgr Studies  Any Race  Any Sex       family  <=50K
# 2  middle aged  Lower studies  Any Race  Any Sex   Non-family  <=50K
# 3          old  Lower studies  Any Race  Any Sex       family  <=50K
# 4        young    Hgr Studies  Any Race  Any Sex       family  <=50K

# %%
#check x-y anonymity
# if it does not satisfy, anonymize again. but we have already anonymized it enough, very minimal rows should disobey it now
def x_y_anony(k, cols):
  counts = merged_df.groupby(cols)['income'].nunique()
  count_k = counts[counts<k]
  return len(count_k)

# %%
val = x_y_anony(4, cols)

# %%
if val > 0:
  print("Does not satisfy x-y anonymity")
else:
  print("satisfies x-y anonymity")
# Out:
# satisfies x-y anonymity

# %%
merged_df
# Out:
#                age      education      race      sex relationship  income
# 0      middle aged    Hgr Studies  Any Race  Any Sex   Non-family   <=50K
# 1              old    Hgr Studies  Any Race  Any Sex       family   <=50K
# 2      middle aged  Lower studies  Any Race  Any Sex   Non-family   <=50K
# 3              old  Lower studies  Any Race  Any Sex       family   <=50K
# 4            young    Hgr Studies  Any Race  Any Sex       family   <=50K
# ...            ...            ...       ...      ...          ...     ...
# 48837  middle aged    Hgr Studies  Any Race  Any Sex   Non-family  <=50K.
# 48838          old  Lower studies  Any Race  Any Sex   Non-family  <=50K.
# 48839  middle aged    Hgr Studies  Any Race  Any Sex       family  <=50K.
# 48840  middle aged    Hgr Studies  Any Race  Any Sex       family  <=50K.
# 48841  middle aged    Hgr Studies  Any Race  Any Sex       family   >50K.
#
# [48842 rows x 6 columns]

# %% [markdown]
# # X-Y Linkability

# %%
def linkThresh(df):
  groups = df.groupby(cols)
  max_threshold = 0.0
  for names, grps in groups:
    fractions = grps.iloc[:,-1].value_counts()
    rows = len(grps)
    values = fractions/rows
    max_threshold = values.max()
  return max_threshold

# %%
val = linkThresh(merged_df)
print("Dataset satisfies X-Y linkability with threshold ", val)
# Out:
# Dataset satisfies X-Y linkability with threshold  0.6427718040621266

# %% [markdown]
# # Entropy l-Diversity

# %%
def entropyL(df):
  groups = df.groupby(cols)
  l = 100
  for names, grps in groups:
    # print("new group")
    counts = grps.iloc[:,-1].value_counts()
    rows = len(grps)
    log_val = 0.0
    for item in counts:
      log_val += -(item/rows)*np.log2(item/rows)
      # print(log_val)
    l = min(l, log_val)
  return l

# %%
entropyL(merged_df)
# Out:
# 1.0458014980332335

# %% [markdown]
# # recursive(c,l) diversity

# %%
def recursiveCL(df, c, l):
    groups = df.groupby(cols)
    for names, grps in groups:
        counts = grps.iloc[:, -1].value_counts()
        # print(counts)
        counts_sorted = counts.sort_values(ascending=False)  # Sort counts in descending order
        # print(counts_sorted)

        # Check condition
        first_value_count = counts_sorted.iloc[0]  # Get count of the first (largest) value
        last_half_sum = counts_sorted.iloc[len(counts_sorted) - l:].sum()  # Sum of counts of last half of values

        if first_value_count > c * last_half_sum:
            return False
    return True

# %%
val = recursiveCL(merged_df, 168, 1)
print("Does it follow c-l with c,l predefined? ", val)
# Out:
# Does it follow c-l with c,l predefined?  True

# %%
val
# Out:
# False
